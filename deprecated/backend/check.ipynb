# %%
import json 
embedding_file = "paper_embeddings.json"
papers_file = "papers.json"
import numpy as np

# %%
with open(embedding_file, "r") as f:
    paper_embeddings = json.load(f)

# %%
len(paper_embeddings)
# Out:
# 1000

# %%
for k, v in paper_embeddings.items():
    if not isinstance(v, np.ndarray) or not np.issubdtype(v.dtype, np.number):
        print(f"Non-numeric embedding at key: {k}")
# Out:
# Non-numeric embedding at key: 2003-0001
# Non-numeric embedding at key: 2003-0002
# Non-numeric embedding at key: 2003-0003
# Non-numeric embedding at key: 2003-0004
# Non-numeric embedding at key: 2003-0005
# Non-numeric embedding at key: 2003-0006
# Non-numeric embedding at key: 2003-0007
# Non-numeric embedding at key: 2003-0008
# Non-numeric embedding at key: 2003-0009
# Non-numeric embedding at key: 2003-0010
# Non-numeric embedding at key: 2003-0011
# Non-numeric embedding at key: 2003-0012
# Non-numeric embedding at key: 2003-0013
# Non-numeric embedding at key: 2003-0014
# Non-numeric embedding at key: 2003-0015
# Non-numeric embedding at key: 2003-0016
# Non-numeric embedding at key: 2003-0017
# Non-numeric embedding at key: 2003-0018
# Non-numeric embedding at key: 2003-0019
# Non-numeric embedding at key: 2003-0020
# Non-numeric embedding at key: 2003-0021
# Non-numeric embedding at key: 2003-0022
# Non-numeric embedding at key: 2003-0023
# ...
